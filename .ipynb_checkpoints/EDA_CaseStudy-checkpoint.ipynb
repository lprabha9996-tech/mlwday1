# %% [markdown]
# Objective of Exploratory Data Analysis
# -->To bring out the quality of the data and make it ready for machine learning modelling

# %%
#Import Libraries
import numpy as np#faster data processing(arrays)
import pandas as pd#EDA Purpose

# %%
#Import Libraries
import numpy as np#faster data processing(arrays)
import pandas as pd#EDA Purpose

# %%
#Loading the data
data=pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Understanding the data -->info(),describe(),columns(),unique(),value_count():
data.info()#complete information of the dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
#reading columns 
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
#we will separate the columns
data.dtypes;
data.select_dtypes(include='object') #object columns
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\dmbk ratnakar\AppData\Local\Temp\ipykernel_4056\4001261745.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object') #object columns
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#Total number of passengers in the ship
print('Total number of passengers in the ship are',len(data))
# Out:
# Total number of passengers in the ship are 891

# %%
#Statistical Distribution -->describe()
data.describe(include='object')
#top returns most occuring value
#freq returns the count of the most occuring value
# Out:
# C:\Users\dmbk ratnakar\AppData\Local\Temp\ipykernel_4056\1386211376.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
#we try to undertsand the unique values in the columns
data['Sex'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['Embarked'].unique() #Embarked is place of travel
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
data['Cabin'].unique();
data['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
#Count of each unique value
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts().head(30) #head() it returns top samples by default
#it is
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
#to get random samples in the dataset
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 398          399         0       2                         Pain, Dr. Alfred
# 157          158         0       3                          Corn, Mr. Harry
# 736          737         0       3  Ford, Mrs. Edward (Margaret Ann Watson)
# 823          824         1       3                       Moor, Mrs. (Beila)
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 614          615         0       3          Brocklebank, Mr. William Alfred
# 13            14         0       3              Andersson, Mr. Anders Johan
# 566          567         0       3                     Stoytcheff, Mr. Ilia
# 765          766         1       1     Hogeboom, Mrs. John C (Anna Andrews)
# 0              1         0       3                  Braund, Mr. Owen Harris
# 205          206         0       3               Strom, Miss. Telma Matilda
# 197          198         0       3         Olsen, Mr. Karl Siegwart Andreas
# 113          114         0       3                  Jussila, Miss. Katriina
# 731          732         0       3                 Hassan, Mr. Houssein G N
# 724          725         1       1            Chambers, Mr. Norman Campbell
#
#         Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# 398    male  23.0      0      0           244278   10.5000          NaN
# 157    male  30.0      0      0  SOTON/OQ 392090    8.0500          NaN
# 736  female  48.0      1      3       W./C. 6608   34.3750          NaN
# 823  female  27.0      0      1           392096   12.4750         E121
# 27     male  19.0      3      2            19950  263.0000  C23 C25 C27
# 614    male  35.0      0      0           364512    8.0500          NaN
# 13     male  39.0      1      5           347082   31.2750          NaN
# 566    male  19.0      0      0           349205    7.8958          NaN
# 765  female  51.0      1      0            13502   77.9583          D11
# 0      male  22.0      1      0        A/5 21171    7.2500          NaN
# 205  female   2.0      0      1           347054   10.4625           G6
# 197    male  42.0      0      1             4579    8.4042          NaN
# 113  female  20.0      1      0             4136    9.8250          NaN
# 731    male  11.0      0      0             2699   18.7875          NaN
# 724    male  27.0      1      0           113806   53.1000           E8
#
#     Embarked
# 398        S
# 157        S
# 736        S
# 823        S
# 27         S
# 614        S
# 13         S
# 566        S
# 765        S
# 0          S
# 205        S
# 197        S
# 113        S
# 731        C
# 724        S

# %%
#DataVisualization --> matplotlib,seaborn,plotly
import matplotlib.pyplot as plt #!pip install matplotlib

# %%
#Distribution of Age
plt.hist(data['Age'],bins=15,color='red')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.show()

# %%
#display the count on bars in histogram
#Distribution of Age
counts,edges,bars=plt.hist(data['Age'],bins=15,color='red')
print(counts)
print(bars)
plt.hist(data['Age'],bins=15,color='red')
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
#bar plot representation
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
#bar plot representation
data['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
549/(549+342)
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#Pie chart
plt.pie(x=labels,labels=['Dead','Alive'],
        colors=['pink','violet'],
        autopct="%.1f%%",
        shadow=True)
plt.title("Survived Distribution")
plt.legend()
plt.show()

# %%
plt.pie(x= [577,314],
        labels=['M','F'],
        colors=['violet','orange'],
        autopct="%.1f%%",
        shadow=True)
plt.title("Gender Distribution")
plt.legend()
plt.show()

# %%
#pairwise relationship -->scatterplot()
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare Distribution")
plt.show()

# %%
import plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pip install plotly
# Out:
# Collecting plotly
#   Using cached plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Using cached narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from plotly) (26.3)
# Using cached plotly-6.9.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.24.0-py3-none-any.whl (461 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.24.0 plotly-6.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install cufflinks
# Out:
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ---------------------------------------- 0.0/81.7 kB ? eta -:--:--
#      ----------------------------------- ---- 71.7/81.7 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 81.7/81.7 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in c:\users\dmbk ratnakar\appdata\local\programs\python\python312\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68558 sha256=efa36732199afa35fd00ede80e981aed7917c6b3a1c20a61b8210d659399405d
#   Stored in directory: c:\users\dmbk ratnakar\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# Installing collected packages: colorlover, setuptools, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 setuptools-83.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly as py
import plotly.graph_objects as go #for interactive graphs
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.7.0.min"</script>

# %%
#Let's visualize histogram
trace = go.Histogram(x = data['Age'],
                     nbinsx=20,
                     marker={'color':'maroon'})
#layout define for the graph
layout = go.Layout(title="Age Distribution")
#we combine the trace with the layout to display the figure
fig = go.Figure(data=trace,layout = layout)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="a1880306-7920-4106-a436-bc5d0ed8be67" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a1880306-7920-4106-a436-bc5d0ed8be67")) {                    Plotly.newPlot(                        "a1880306-7920-4106-a436-bc5d0ed8be67",                        [{"marker":{"color":"maroon"},"nbinsx":20,"x":{"dtype":"f8","bdata":"AAAAAAAANkAAAAAAAABDQAAAAAAAADpAAAAAAACAQUAAAAAAAIBBQAAAAAAAAPh\u002fAAAAAAAAS0AAAAAAAAAAQAAAAAAAADtAAAAAAAAALEAAAAAAAAAQQAAAAAAAAE1AAAAAAAAANEAAAAAAAIBDQAAAAAAAACxAAAAAAACAS0AAAAAAAAAAQAAAAAAAAPh\u002fAAAAAAAAP0AAAAAAAAD4fwAAAAAAgEFAAAAAAAAAQUAAAAAAAAAuQAAAAAAAADxAAAAAAAAAIEAAAAAAAABDQAAAAAAAAPh\u002fAAAAAAAAM0AAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAREAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAACAUEAAAAAAAAA8QAAAAAAAAEVAAAAAAAAA+H8AAAAAAAA1QAAAAAAAADJAAAAAAAAALEAAAAAAAABEQAAAAAAAADtAAAAAAAAA+H8AAAAAAAAIQAAAAAAAADNAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAAyQAAAAAAAABxAAAAAAAAANUAAAAAAAIBIQAAAAAAAAD1AAAAAAABAUEAAAAAAAAD4fwAAAAAAADVAAAAAAACAPEAAAAAAAAAUQAAAAAAAACZAAAAAAAAANkAAAAAAAABDQAAAAAAAgEZAAAAAAAAAEEAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAA
AAAAAD4fwAAAAAAAPh\u002fAAAAAAAAPUAAAAAAAIBEQAAAAAAAgEZAAAAAAACARkAAAAAAAAAAQAAAAAAAADhAAAAAAAAAPEAAAAAAAAA5QAAAAAAAAEJAAAAAAAAAOEAAAAAAAABEQAAAAAAAAPh\u002fAAAAAAAACEAAAAAAAABFQAAAAAAAADdAAAAAAAAA+H8AAAAAAAAuQAAAAAAAADlAAAAAAAAA+H8AAAAAAAA8QAAAAAAAADZAAAAAAAAAQ0AAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAREAAAAAAAAA9QAAAAAAAgEZAAAAAAACAQUAAAAAAAAD4fwAAAAAAAD5AAAAAAAAATkAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAOEAAAAAAAAA5QAAAAAAAADJAAAAAAAAAM0AAAAAAAAA2QAAAAAAAAAhAAAAAA ...

# %%
#Now we will display for piechart
trace = go.Pie(labels=['Dead','Alive'],
               values=labels,
              )
layout = go.Layout(title = 'Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="d3846abf-87c5-408c-a8ba-94d3df018015" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d3846abf-87c5-408c-a8ba-94d3df018015")) {                    Plotly.newPlot(                        "d3846abf-87c5-408c-a8ba-94d3df018015",                        [{"labels":["Dead","Alive"],"values":[549,342],"type":"pie"}],                        {"title":{"text":"Survived Distribution"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermapbox":[{"type":"scattermapbox","marker":{"colorbar":{"outlinewidth":0,"ticks": ...
#
# var gd = document.getElementById('d3846abf-87c5-408c-a8ba-94d3df018015');
# var x = new MutationObserver(function (mutations, observer) {{

# %%
#Box plot and Scatter Plot
trace = go.Box(x=data['Pclass'],
               y=data['Age'],
               marker={'color':'red'})
layout = go.Layout(title="Age vs pclass Distribution")
fig = go.Figure(data=trace,layout = layout)
fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="7902768d-4075-4377-ae60-cf7216b96b2b" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7902768d-4075-4377-ae60-cf7216b96b2b")) {                    Plotly.newPlot(                        "7902768d-4075-4377-ae60-cf7216b96b2b",                        [{"marker":{"color":"red"},"x":{"dtype":"i1","bdata":"..."},"y":{"dtype":"f8","bdata":"AAAAAAAANkAAAAAAAABDQAAAAAAAADpAAAAAAACAQUAAAAAAAIBBQAAAAAAAAPh\u002fAAAAAAAAS0AAAAAAAAAAQAAAAAAAADtAAAAAAAAALEAAAAAAAAAQQAAAAAAAAE1AAAAAAAAANEAAAAAAAIBDQAAAAAAAACxAAAAAAACAS0AAAAAAAAAAQAAAAAAAAPh\u002fAAAAAAAAP0AAAAAAAAD4fwAAAAAAgEFAAAAAAAAAQUAAAAAAAAAuQAAAAAAAADxAAAAAAAAAIEAAAAAAAABDQAAAAAAAAPh\u002fAAAAAAAAM0AAAAAAAAD4fwAAAAAAAPh\u002fAAAAAA
AAAAAAAPA\u002fAAAAAAAAIkAAAAAAAAD4fwAAAAAAgEZAAAAAAAAA+H8AAAAAAAA8QAAAAAAAgE5AAAAAAAAAEEAAAAAAAADwPwAAAAAAADVAAAAAAAAATEAAAAAAAAAyQAAAAAAAAPh\u002fAAAAAAAASUAAAAAAAAA+QAAAAAAAAEJAAAAAAAAA+H8AAAAAAAD4fwAAAAAAACJAAAAAAAAA8D8AAAAAAAAQQAAAAAAAAPh\...\\u002fAAAAAACAQEAAAAAAAAA+QAAAAAAAADZAAAAAAAAARUAAAAAAAAA2QAAAAAAAADpAAAAAAAAAM0AAAAAAAABCQAAAAAAAADhAAAAAAAAAOEAAAAAAAAD4fwAAAAAAgDdAAAAAAAAAAEAAAAAAAAD4fwAAAAAAAElAAAAAAAAA+H8AAAAAAAD4fwAAAAAAADNAAAAAAAAA+H8AAAAAAAD4f3E9CtejcO0\u002fAAAAAAAA+H8AAAAAAAAxQAAAAAAAAD5AAAAAAAAAPkAAAAAAAAA4QAAAAAAAADJAAAAAAAAAOkAAAAAAAAA8QAAAAAAAgEVAAAAAAAAAOkAAAAAAAAA4QAAAAAAAAEtAAAAAAAAAP0AAAAAAAABEQAAAAAAAADZAAAAAAAAAO0AAAAAAAAA+QAAAAAAAADZAAAAAAAAA+H8AAAAAAABCQAAAAAAAgE5AAAAAAAAAQkAAAAAAAAA\u002fQAAAAAAAADBAAAAAAAAA+H8AAAAAAMBGQAAAAAAAAENAAAAAAAAAMEAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAPUAAAAAAAIBEQAAAAAAAgEZAAAAAAACARkAAAAAAAAAAQAAAAAAAADhAAAAAAAAAPEAAAAAAAAA5QAAAAAAAAEJAAAAAAAAAOEAAAAAAAABEQAAAAAAAAPh\u002fAAAAAAAACEAAAAAAAABFQAAAAAAAADdAAAAAAAAA+H8AAAAAAAAuQAAAAAAAADlAAAAAAAAA+H8AAAAAAAA8QAAAAAAAADZAAAAAAAAAQ0AAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAREAAAAAAAAA9QAAAAAAAgEZAAAAAAACAQUAAAAAAAAD4fwAAAAAAAD5AAAAAAAAATkAAAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAAOEAAAAAAAAA5QAAAAAAAADJAAAAAAAAAM0AAAAAAAAA2QAAAAAAAAAhA ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(data['Age'].mean())
# Out:
# 29.69911764705882

# %%
#We can fill the Age column missing values with mean
data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True);
data.isnull().sum()
# Out:
# C:\Users\dmbk ratnakar\AppData\Local\Temp\ipykernel_4056\3956070026.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True);
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
